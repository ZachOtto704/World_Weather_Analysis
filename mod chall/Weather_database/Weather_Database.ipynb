# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size=1500)
lngs = np.random.uniform(-90,90, size=1500)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(46.94756068194272, 42.26463892642431), (-3.3823706885999485, 36.09606165212868), (56.8404009154541, 65.3142129450903), (-44.763145155273925, -20.27470542604364), (-2.6141282893101163, -84.33831950931028), (-38.529124066793834, -10.73829404393291), (66.2005958957449, -83.17576189641179), (-56.531259570602195, -6.09483898922754), (22.358359872952363, 0.16134601925337222), (-48.16902456832143, 75.49244051096409), (-33.50269509884534, 35.0552010131578), (-6.659511707824109, -35.10335131845792), (12.656160352601418, 0.02526239905724026), (81.52939808918131, -57.49360249776051), (15.65257007804091, 2.891357993343888), (18.203482303914498, 8.577083044440599), (-20.851116077888534, 59.11130750002161), (79.77364174971518, -27.153186642459374), (4.043783628001194, 65.71189248278526), (-14.245912828490034, -31.256179268212364), (68.04464260304096, -81.95946186734605), (82.39801240210076, -29.547049094129747), (76.95316197190897, -83.76889998023341), (16.474621315475474, -2.9843515186847185), (28.21343496986296, -35.251879698761215), (-3.447321748579597, 83.2898930603647), (-25.33483103571561, -31.163811252886504), (0.11620291220040713, -31.78754349199174), (-56.70644045776499, 45.072415450581104), (-11.975612372390813, -9.96247518676499), (-14.391855243787262, -85.02831961625623), (16.908403648090655, -88.34148408672299), (7.62402977911934, 66.43458023854012), (39.842867350303095, 60.61037409934454), (-39.903566660661134, -54.211062084181606), (-31.75397551588368, 60.71508700685945), (65.96744981621768, -18.512795038333138), (-80.1283264167379, -9.208268825697814), (10.4216856181461, -52.06956538170944), (-42.82489768261192, 6.806816521847196), (10.095737387674149, -84.24733615218649), (-83.7259402564219, -11.958203240209258), (34.95795655259796, -0.16760981856010915), (-89.11328972171123, -62.77596313783263), (2.6842378408552037, -75.50768643615172), (-32.112418290385406, -31.895247135663453), (-69.66687385020396, 82.24567632521709), (-35.46917821022735, -42.80032294517112), (-55.65865763347603, 31.518441570794494), (51.90578116607293, -1.8817340921874575), (46.322808521578395, -0.20324580834349604), (-38.19354882402602, -22.10836702878177), (24.647602704130705, 81.77674518682429), (-28.614995492865766, -42.01911324081334), (19.35247145214926, -86.59883669065916), (-3.4264561077108198, -58.54672228040428), (-82.16555330710362, 25.000379732968725), (41.538085484996316, 60.84430505060391), (27.051682555221916, 74.58216363483706), (-54.89521045183833, 43.73451907048931), (70.47240337087646, -27.24625563161741), (42.72257051067382, -15.84327051942158), (68.6330317259073, 43.06599877565222), (64.11508963362161, -77.69417527451581), (-67.50403447511032, -81.69551366226153), (33.4621573064552, -57.55221069704109), (-74.14452794495305, -38.81905439530505), (59.39340203324747, 11.343575591076828), (89.66965733946091, 0.008927131071985173), (38.57016233997902, -10.955465588348801), (-85.87948489304084, -9.267352841654358), (56.053649111028506, 52.22832712163742), (56.524001752022485, 70.93152788586457), (-85.11978777078329, 22.53362139905731), (20.738104469835505, -37.50206718013172), (39.104253205822175, 45.81434152328464), (-30.20482196248159, 56.80632484158704), (-52.2722148990217, -48.542496812535276), (3.0197213765136013, 76.40780424849495), (67.1812525971014, 69.31544172776128), (51.89942504818947, -63.197271279746694), (-6.413836894299706, 12.882567720354487), (62.695677019125554, -62.693320247473025), (89.69520740150048, -70.07101025742321), (11.239375204904874, -24.882452614015705), (-36.34647812420183, -32.23163808574354), (-81.72399608944627, -47.93447402847345), (-66.41190233214797, 12.666210748777587), (1.4299163169676774, -77.6767137783313), (51.04727155535829, -51.192639126807556), (17.78070237514578, -37.3472763790129), (-59.476804765476075, -4.120631964507822), (27.875448405881684, -82.47595805648857), (-27.88447629701335, -28.24752732560394), (6.8064034739655455, 51.14486016075287), (48.56440168416077, 66.02493686319568), (47. ...

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
cities
# Out:
# ['krasnoarmeyskiy',
#  'mto wa mbu',
#  'chervishevo',
#  'arraial do cabo',
#  'salinas',
#  'jamestown',
#  'attawapiskat',
#  'cape town',
#  'tessalit',
#  'mahebourg',
#  'port shepstone',
#  'rio tinto',
#  'bogande',
#  'upernavik',
#  'filingue',
#  'arlit',
#  'bambous virieux',
#  'illoqqortoormiut',
#  'mahibadhoo',
#  'maceio',
#  'clyde river',
#  'qaanaaq',
#  'tombouctou',
#  'ribeira grande',
#  'matara',
#  'vila velha',
#  'touros',
#  'east london',
#  'hualmay',
#  'dangriga',
#  'kulhudhuffushi',
#  'druzhba',
#  'mar del plata',
#  'saint-philippe',
#  'dalvik',
#  'mana',
#  'san juan',
#  'wahran',
#  'ushuaia',
#  'yaguara',
#  'busselton',
#  'cidreira',
#  'port elizabeth',
#  'cheltenham',
#  'niort',
#  'mauganj',
#  'tulum',
#  'itacoatiara',
#  'bredasdorp',
#  'turtkul',
#  'makrana',
#  'muros',
#  'kamenka',
#  'iqaluit',
#  'punta arenas',
#  'saint george',
#  'rakkestad',
#  'barentsburg',
#  'colares',
#  'hermanus',
#  'mendeleyevsk',
#  'vikulovo',
#  'ponta do sol',
#  'culfa',
#  'muli',
#  'yar-sale',
#  'havre-saint-pierre',
#  'soyo',
#  'pangnirtung',
#  'sao filipe',
#  'la llanada',
#  'bonavista',
#  'tampa',
#  'eyl',
#  'zhezkazgan',
#  'saumur',
#  'adrar',
#  'vardo',
#  'uwayl',
#  'souillac',
#  'nuuk',
#  'berehove',
#  'banda aceh',
#  'hithadhoo',
#  'cockburn town',
#  'mizdah',
#  'belushya guba',
#  'coquimbo',
#  'susehri',
#  'belyy yar',
#  'yeehaw junction',
#  'kalmunai',
#  'taolanaro',
#  'leibnitz',
#  'georgetown',
#  'kavaratti',
#  'talnakh',
#  'nampula',
#  'ilulissat',
#  'antalaha',
#  'challans',
#  'rivera',
#  'tevriz',
#  'krasnousolskiy',
#  'boundiali',
#  'chicama',
#  'kankon',
#  'monrovia',
#  'port alfred',
#  'berlevag',
#  'hawwarah',
#  'lixourion',
#  'kruisfontein',
#  'kedougou',
#  'chiman',
#  'barcelona',
#  'jahrom',
#  'dingle',
#  'dudinka',
#  'amderma',
#  'vestmanna',
#  'tasiilaq',
#  'longyearbyen',
#  'rosetta',
#  'santiago del estero',
#  'begun',
#  'port-gentil',
#  'porto walter',
#  'severodvinsk',
#  'sorland',
#  'grand river south east',
#  'saurimo',
#  'kovylkino',
#  'carutapera',
#  'upata',
#  'mahadday weyne',
#  'evinayong',
#  'malakal',
#  'siyabuswa',
#  'thunder bay',
#  'tahoua',
#  'sao joao del rei',
#  'puksoozero',
#  'dikson',
#  'koygorodok',
#  'xai-xai',
#  'kidal',
#  'nanortalik',
#  'umzimvubu',
#  'nur',
#  'brae',
#  'saint-joseph',
#  'bondo',
#  'chuy',
#  'sergeyevka',
#  'maldonado',
#  'comodoro rivadavia',
#  'sept-iles',
#  'antofagasta',
#  'virarajendrapet',
#  'luderitz',
#  'mbaiki',
#  'awjilah',
#  'cururupu',
#  'lebu',
#  'atar',
#  'carnarvon',
#  'vila franca do campo',
#  'chadiza',
#  'korla',
#  'guapore',
#  'tazovskiy',
#  'jonkoping',
#  'geraldton',
#  'dharmadam',
#  'karlstad',
#  'dannenberg',
#  'castro',
#  'teguise',
#  'aleksandrov gay',
#  'aljezur',
#  'klaksvik',
#  'okoneshnikovo',
#  'grado',
#  'ibra',
#  'salinopolis',
#  'oranjestad',
#  'port-cartier',
#  'sinnamary',
#  'pisco',
#  'umm kaddadah',
#  'atbasar',
#  'sao domingos',
#  'katete',
#  'wampusirpi',
#  'ullal',
#  'raudeberg',
#  'san lawrenz',
#  'sahrak',
#  'kudahuvadhoo',
#  'mecca',
#  'hobyo',
#  'victoria',
#  'olafsvik',
#  'iquique',
#  'pyshchug',
#  'harper',
#  'kargasok',
#  'maturin',
#  'libreville',
#  'ambo',
#  'lisakovsk',
#  'nandikotkur',
#  'phalodi',
#  'wajir',
#  'tumannyy',
#  'kegayli',
#  'mtwara',
#  'hendersonville',
#  'lokosovo',
#  'paita',
#  'lagoa',
#  'ngaoundere',
#  'uricani',
#  'margate',
#  'caravelas',
#  'san lorenzo',
#  'ibotirama',
#  'eskasem',
#  'manono',
#  'tashtyp',
#  'derbent',
#  'linhares',
#  'san julian',
#  'mosalsk',
#  'san cristobal',
#  'paamiut',
#  'carballo',
#  'karaul',
#  'saryshagan',
#  'cayenne',
#  'kumluca',
#  'nicolas bravo',
#  'hunza',
#  'dhidhdhoo',
#  'meulaboh',
#  'prieska',
#  'namibe',
#  'hambantota',
#  'nizwa',
#  'lukovetskiy',
#  'maniitsoq',
#  'kuche',
#  'khorramabad',
#  'faya',
#  'mehamn',
#  'genoa',
#  'laguna',
#  'sioux lookout',
#  'lahij',
#  'chimoio',
#  'divnomorskoye',
#  'goderich',
#  'solovetskiy',
#  'zenzeli',
#  'bocaiuva',
#  'qeshm',
#  'boddam',
#  'clearwater',
#  'wooster',
#  'ayagoz',
#  'fiumicino',
#  'kasongo-lunda',
#  'olinda',
#  'springdale',
#  'sur',
#  'pimentel',
#  'balkanabat',
#  'baie-comeau',
#  'mahanje',
#  'maarianhamina',
#  'karakendzha',
#  'vytegra',
#  'alanya',
#  'semey',
#  'lakselv',
#  'gravdal',
#  'saint-leu',
#  'lucapa',
#  'ushtobe',
#  'inhambane',
#  'synya',
#  'pietarsaari',
#  'am timan',
#  'urdoma',
#  'macusani',
#  'diffa',
#  'patti',
#  'porto novo',
#  'kazalinsk',
#  'kapuskasing',
#  'torbay',
#  'tulsipur',
#  'coruripe',
#  'dondo',
#  'saint-pascal',
#  'oranjemund',
#  'oksovskiy',
#  'san ignacio',
#  'kalomo',
#  'chake chake',
#  'mizan teferi',
#  'elliot lake',
#  'grootfontein',
#  'piryion',
#  'kutum',
#  'karatau',
#  'bilma',
#  'votkinsk',
#  'altamira',
#  'douentza',
#  'bosaso',
#  'bertoua',
#  'abu zabad',
#  'saldanha',
#  'putina',
#  'araguatins',
#  'oum hadjer',
#  'tallahassee',
#  'solntsevo',
#  'urumqi',
#  'bacabal',
#  'kuznechnoye',
#  'sambava',
#  'kommunar',
#  'doha',
#  'punto fijo',
#  'ulvik',
#  'los llanos de aridane',
#  'borova',
#  'lasa',
#  'narsaq',
#  'maputo',
#  'richards bay',
#  'igarapava',
#  'piacabucu',
#  'carmaux',
#  'sao miguel do araguaia',
#  'villazon',
#  'wielun',
#  'eirunepe',
#  'bom jesus',
#  'leh',
#  'bridlicna',
#  'cabedelo',
#  'santo domingo',
#  'khurai',
#  'damavand',
#  'sindor',
#  'inirida',
#  'marsa matruh',
#  'fougamou',
#  'san rafael',
#  'warqla',
#  'seshcha',
#  'bulqize',
#  'ostrovnoy',
#  'tabarqah',
#  'grakhovo',
#  'farafangana',
#  'waynesville',
#  'afua',
#  'montero',
#  'maltahohe',
#  'falavarjan',
#  'portel',
#  'port blair',
#  'stokmarknes',
#  'bouna',
#  'bengkulu',
#  'abu dhabi',
#  'kulu',
#  'opuwo',
#  'muisne',
#  'sterlibashevo',
#  'camboriu',
#  'callaway',
#  'filadelfia',
#  'salta',
#  'marystown',
#  'serebryansk',
#  'varsag',
#  'alford',
#  'bathsheba',
#  'melong',
#  'tsihombe',
#  'hofn',
#  'san antonio',
#  'bolu',
#  'mayumba',
#  'mortka',
#  'plettenberg bay',
#  'rawson',
#  'crossville',
#  'jacareacanga',
#  'yumaguzino',
#  'taltal',
#  'canela',
#  'marcona',
#  'bauchi',
#  'tigzirt',
#  'suez',
#  'puerto lempira',
#  'azimur',
#  'benguela',
#  'puerto maldonado',
#  'likasi',
#  'saint anthony',
#  'tsybuliv',
#  'villa bruzual',
#  'asfi',
#  'apac',
#  'ciro marina',
#  'brunico',
#  'viedma',
#  'portobelo',
#  'mayahi',
#  'tres arroyos',
#  'tuscaloosa',
#  'krasnyy yar',
#  'bandarbeyla',
#  'padang',
#  'apatity',
#  'belleville',
#  'jumla',
#  'mihail kogalniceanu',
#  'riesa',
#  'conceicao da barra',
#  'zilair',
#  'marsh harbour',
#  'abadiania',
#  'biltine',
#  'uray',
#  'kars',
#  'axim',
#  'kongolo',
#  'miranda de ebro',
#  'agsu',
#  'horta',
#  'corovode',
#  'birjand',
#  'guanare',
#  'dubenskiy',
#  'rondonopolis',
#  'kathor',
#  'umm lajj',
#  'tonj',
#  'eganville',
#  'santa fe',
#  'llanera',
#  'husavik',
#  'conde',
#  'amalapuram',
#  'birao',
#  'hornepayne',
#  'ust-koksa',
#  'ereymentau',
#  'dankov',
#  'jati',
#  'ipswich',
#  'khokhlovo',
#  'sembe',
#  'chisindia',
#  'morondava',
#  'omboue',
#  'codrington',
#  'el doncello',
#  'nathdwara',
#  'caconda',
#  'lethem',
#  'gavle',
#  'keti bandar',
#  'koplik',
#  'snezhnogorsk',
#  'sao joao da barra',
#  'barreirinhas',
#  'strezhevoy',
#  'narkevychi',
#  'kalisz',
#  'havelock',
#  'novoye atlashevo',
#  'voloshka',
#  'rundu',
#  'nouadhibou',
#  'sedelnikovo',
#  'pitimbu',
#  'mananjary',
#  'el copey',
#  'tubuala',
#  'bougouni',
#  'eresos',
#  'sindand',
#  'beisfjord',
#  'honningsvag',
#  'tapaua',
#  'sanlucar la mayor',
#  'longlac',
#  'garissa',
#  'cap malheureux',
#  'aktau',
#  'veselynove',
#  'malartic',
#  'montepuez',
#  'ochakiv',
#  'chinhoyi',
#  'lipin bor',
#  'kalabo',
#  'nhamunda',
#  'ndele',
#  'ringebu',
#  'la mana',
#  'thinadhoo',
#  'westport',
#  'henties bay',
#  'praia da vitoria',
#  'afonso claudio',
#  'alassio',
#  'outjo',
#  'aksarayskiy',
#  'acarau',
#  'san gavino monreale',
#  'kozhva',
#  'bisira',
#  'vagur',
#  'krasnyy gulyay',
#  'hyeres',
#  'manicore',
#  'reo',
#  'zhovti vody',
#  'formoso do araguaia',
#  'chaplynka',
#  'chimore',
#  'grindavik',
#  'lyantonde',
#  'illapel',
#  'gamba',
#  'mishkino',
#  'ancud',
#  'siva',
#  'vila do maio',
#  'manakara',
#  'vitoria',
#  'anloga',
#  'cassilandia',
#  'marv dasht',
#  'taoudenni',
#  'trifesti',
#  'havoysund',
#  'ambilobe',
#  'shelburne',
#  'farkhor',
#  'andrelandia',
#  'praia',
#  'lancaster',
#  'polovinnoye',
#  'unai',
#  'megion',
#  'hwange',
#  'mapiripan',
#  'abapo',
#  'alta floresta',
#  'mogadishu',
#  'dharchula',
#  'tasgaon',
#  'ozgon',
#  'tabou',
#  'maetaguse',
#  'shujaabad',
#  'apatou',
#  'viligili',
#  'vitry-le-francois',
#  'pyaozerskiy',
#  'loding',
#  'uravakonda',
#  'hamilton',
#  'mango',
#  'sarahan',
#  'ornskoldsvik',
#  'camamu',
#  'borazjan',
#  'hemsedal',
#  'buy',
#  'mocuba',
#  'babanusah',
#  'fort-shevchenko',
#  'calama',
#  'road town',
#  'puerto carreno',
#  'sorvag',
#  'aksarka',
#  'kudinovo',
#  'parabel',
#  'sharjah',
#  'terny',
#  'manadhoo',
#  'barra do garcas',
#  'hima',
#  'nokaneng',
#  'ilmajoki',
#  'kastamonu',
#  'bud',
#  'rio gallegos',
#  'manzil tamim',
#  'antsohihy',
#  'tuljapur',
#  'todiresti',
#  'liman',
#  'sao gabriel da cachoeira',
#  'camana',
#  'joao alfredo',
#  'santa cruz cabralia',
#  'huarmey',
#  'santo antonio do sudoeste',
#  'jalu',
#  'alekseyevka',
#  'sfantu gheorghe',
#  'turukhansk']

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weatherAPI_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weatherAPI_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]   
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})
    except:
        print("City not found. Skipping...")
        pass
    # If an error is experienced, skip the city
    

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | krasnoarmeyskiy
# Processing Record 2 of Set 1 | mto wa mbu
# Processing Record 3 of Set 1 | chervishevo
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | salinas
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | tessalit
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | port shepstone
# Processing Record 12 of Set 1 | rio tinto
# Processing Record 13 of Set 1 | bogande
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | filingue
# Processing Record 16 of Set 1 | arlit
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | mahibadhoo
# Processing Record 20 of Set 1 | maceio
# Processing Record 21 of Set 1 | clyde river
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | tombouctou
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | matara
# Processing Record 26 of Set 1 | vila velha
# Processing Record 27 of Set 1 | touros
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | hualmay
# Processing Record 30 of Set 1 | dangriga
# Processing Record 31 of Set 1 | kulhudhuffushi
# Processing Record 32 of Set 1 | druzhba
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | dalvik
# Processing Record 36 of Set 1 | mana
# Processing Record 37 of Set 1 | san juan
# Processing Record 38 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | yaguara
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | cheltenham
# Processing Record 45 of Set 1 | niort
# Processing Record 46 of Set 1 | mauganj
# Processing Record 47 of Set 1 | tulum
# Processing Record 48 of Set 1 | itacoatiara
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | turtkul
# City not found. Skipping...
# Processing Record 1 of Set 2 | makrana
# Processing Record 2 of Set 2 | muros
# Processing Record 3 of Set 2 | kamenka
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | saint george
# Processing Record 7 of Set 2 | rakkestad
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | colares
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | mendeleyevsk
# Processing Record 12 of Set 2 | vikulovo
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | culfa
# Processing Record 15 of Set 2 | muli
# Processing Record 16 of Set 2 | yar-sale
# Processing Record 17 of Set 2 | havre-saint-pierre
# Processing Record 18 of Set 2 | soyo
# Processing Record 19 of Set 2 | pangnirtung
# Processing Record 20 of Set 2 | sao filipe
# Processing Record 21 of Set 2 | la llanada
# Processing Record 22 of Set 2 | bonavista
# Processing Record 23 of Set 2 | tampa
# Processing Record 24 of Set 2 | eyl
# Processing Record 25 of Set 2 | zhezkazgan
# Processing Record 26 of Set 2 | saumur
# Processing Record 27 of Set 2 | adrar
# Processing Record 28 of Set 2 | vardo
# Processing Record 29 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 30 of Set 2 | souillac
# Processing Record 31 of Set 2 | nuuk
# Processing Record 32 of Set 2 | berehove
# Processing Record 33 of Set 2 | banda aceh
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | cockburn town
# Processing Record 36 of Set 2 | mizdah
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | coquimbo
# Processing Record 39 of Set 2 | susehri
# Processing Record 40 of Set 2 | belyy yar
# Processing Record 41 of Set 2 | yeehaw junction
# City not found. Skipping...
# Processing Record 42 of Set 2 | kalmunai
# Processing Record 43 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 2 | leibnitz
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | talnakh
# Processing Record 48 of Set 2 | nampula
# Processing Record 49 of Set 2 | ilulissat
# Processing Record 50 of Set 2 | antalaha
# Processing Record 1 of Set 3 | challans
# Processing Record 2 of Set 3 | rivera
# Processing Record 3 of Set 3 | tevriz
# Processing Record 4 of Set 3 | krasnousolskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | boundiali
# Processing Record 6 of Set 3 | chicama
# Processing Record 7 of Set 3 | kankon
# Processing Record 8 of Set 3 | monrovia
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | berlevag
# Processing Record 11 of Set 3 | hawwarah
# City not found. Skipping...
# Processing Record 12 of Set 3 | lixourion
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | kedougou
# Processing Record 15 of Set 3 | chiman
# Processing Record 16 of Set 3 | barcelona
# Processing Record 17 of Set 3 | jahrom
# City not found. Skipping...
# Processing Record 18 of Set 3 | dingle
# Processing Record 19 of Set 3 | dudinka
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | vestmanna
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | rosetta
# Processing Record 25 of Set 3 | santiago del estero
# Processing Record 26 of Set 3 | begun
# Processing Record 27 of Set 3 | port-gentil
# Processing Record 28 of Set 3 | porto walter
# Processing Record 29 of Set 3 | severodvinsk
# Processing Record 30 of Set 3 | sorland
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | saurimo
# Processing Record 33 of Set 3 | kovylkino
# Processing Record 34 of Set 3 | carutapera
# Processing Record 35 of Set 3 | upata
# Processing Record 36 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 37 of Set 3 | evinayong
# Processing Record 38 of Set 3 | malakal
# Processing Record 39 of Set 3 | siyabuswa
# Processing Record 40 of Set 3 | thunder bay
# Processing Record 41 of Set 3 | tahoua
# Processing Record 42 of Set 3 | sao joao del rei
# Processing Record 43 of Set 3 | puksoozero
# Processing Record 44 of Set 3 | dikson
# Processing Record 45 of Set 3 | koygorodok
# Processing Record 46 of Set 3 | xai-xai
# Processing Record 47 of Set 3 | kidal
# Processing Record 48 of Set 3 | nanortalik
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | nur
# Processing Record 1 of Set 4 | brae
# Processing Record 2 of Set 4 | saint-joseph
# Processing Record 3 of Set 4 | bondo
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | sergeyevka
# Processing Record 6 of Set 4 | maldonado
# Processing Record 7 of Set 4 | comodoro rivadavia
# Processing Record 8 of Set 4 | sept-iles
# Processing Record 9 of Set 4 | antofagasta
# Processing Record 10 of Set 4 | virarajendrapet
# Processing Record 11 of Set 4 | luderitz
# Processing Record 12 of Set 4 | mbaiki
# Processing Record 13 of Set 4 | awjilah
# Processing Record 14 of Set 4 | cururupu
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | atar
# Processing Record 17 of Set 4 | carnarvon
# Processing Record 18 of Set 4 | vila franca do campo
# Processing Record 19 of Set 4 | chadiza
# Processing Record 20 of Set 4 | korla
# Processing Record 21 of Set 4 | guapore
# Processing Record 22 of Set 4 | tazovskiy
# Processing Record 23 of Set 4 | jonkoping
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | dharmadam
# Processing Record 26 of Set 4 | karlstad
# Processing Record 27 of Set 4 | dannenberg
# Processing Record 28 of Set 4 | castro
# Processing Record 29 of Set 4 | teguise
# Processing Record 30 of Set 4 | aleksandrov gay
# Processing Record 31 of Set 4 | aljezur
# Processing Record 32 of Set 4 | klaksvik
# Processing Record 33 of Set 4 | okoneshnikovo
# Processing Record 34 of Set 4 | grado
# Processing Record 35 of Set 4 | ibra
# Processing Record 36 of Set 4 | salinopolis
# Processing Record 37 of Set 4 | oranjestad
# Processing Record 38 of Set 4 | port-cartier
# Processing Record 39 of Set 4 | sinnamary
# Processing Record 40 of Set 4 | pisco
# Processing Record 41 of Set 4 | umm kaddadah
# Processing Record 42 of Set 4 | atbasar
# Processing Record 43 of Set 4 | sao domingos
# Processing Record 44 of Set 4 | katete
# Processing Record 45 of Set 4 | wampusirpi
# City not found. Skipping...
# Processing Record 46 of Set 4 | ullal
# Processing Record 47 of Set 4 | raudeberg
# Processing Record 48 of Set 4 | san lawrenz
# Processing Record 49 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 50 of Set 4 | kudahuvadhoo
# Processing Record 1 of Set 5 | mecca
# Processing Record 2 of Set 5 | hobyo
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | olafsvik
# Processing Record 5 of Set 5 | iquique
# Processing Record 6 of Set 5 | pyshchug
# Processing Record 7 of Set 5 | harper
# Processing Record 8 of Set 5 | kargasok
# Processing Record 9 of Set 5 | maturin
# Processing Record 10 of Set 5 | libreville
# Processing Record 11 of Set 5 | ambo
# Processing Record 12 of Set 5 | lisakovsk
# Processing Record 13 of Set 5 | nandikotkur
# Processing Record 14 of Set 5 | phalodi
# Processing Record 15 of Set 5 | wajir
# Processing Record 16 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 5 | mtwara
# Processing Record 19 of Set 5 | hendersonville
# Processing Record 20 of Set 5 | lokosovo
# Processing Record 21 of Set 5 | paita
# Processing Record 22 of Set 5 | lagoa
# Processing Record 23 of Set 5 | ngaoundere
# Processing Record 24 of Set 5 | uricani
# Processing Record 25 of Set 5 | margate
# Processing Record 26 of Set 5 | caravelas
# Processing Record 27 of Set 5 | san lorenzo
# Processing Record 28 of Set 5 | ibotirama
# Processing Record 29 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 5 | manono
# Processing Record 31 of Set 5 | tashtyp
# Processing Record 32 of Set 5 | derbent
# Processing Record 33 of Set 5 | linhares
# Processing Record 34 of Set 5 | san julian
# Processing Record 35 of Set 5 | mosalsk
# Processing Record 36 of Set 5 | san cristobal
# Processing Record 37 of Set 5 | paamiut
# Processing Record 38 of Set 5 | carballo
# Processing Record 39 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 5 | cayenne
# Processing Record 42 of Set 5 | kumluca
# Processing Record 43 of Set 5 | nicolas bravo
# Processing Record 44 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 5 | dhidhdhoo
# Processing Record 46 of Set 5 | meulaboh
# Processing Record 47 of Set 5 | prieska
# Processing Record 48 of Set 5 | namibe
# Processing Record 49 of Set 5 | hambantota
# Processing Record 50 of Set 5 | nizwa
# Processing Record 1 of Set 6 | lukovetskiy
# Processing Record 2 of Set 6 | maniitsoq
# Processing Record 3 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 6 | khorramabad
# Processing Record 5 of Set 6 | faya
# Processing Record 6 of Set 6 | mehamn
# Processing Record 7 of Set 6 | genoa
# Processing Record 8 of Set 6 | laguna
# Processing Record 9 of Set 6 | sioux lookout
# Processing Record 10 of Set 6 | lahij
# Processing Record 11 of Set 6 | chimoio
# Processing Record 12 of Set 6 | divnomorskoye
# Processing Record 13 of Set 6 | goderich
# Processing Record 14 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 6 | zenzeli
# Processing Record 16 of Set 6 | bocaiuva
# Processing Record 17 of Set 6 | qeshm
# Processing Record 18 of Set 6 | boddam
# Processing Record 19 of Set 6 | clearwater
# Processing Record 20 of Set 6 | wooster
# Processing Record 21 of Set 6 | ayagoz
# Processing Record 22 of Set 6 | fiumicino
# Processing Record 23 of Set 6 | kasongo-lunda
# Processing Record 24 of Set 6 | olinda
# Processing Record 25 of Set 6 | springdale
# Processing Record 26 of Set 6 | sur
# Processing Record 27 of Set 6 | pimentel
# Processing Record 28 of Set 6 | balkanabat
# Processing Record 29 of Set 6 | baie-comeau
# Processing Record 30 of Set 6 | mahanje
# Processing Record 31 of Set 6 | maarianhamina
# Processing Record 32 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 33 of Set 6 | vytegra
# Processing Record 34 of Set 6 | alanya
# Processing Record 35 of Set 6 | semey
# Processing Record 36 of Set 6 | lakselv
# Processing Record 37 of Set 6 | gravdal
# Processing Record 38 of Set 6 | saint-leu
# Processing Record 39 of Set 6 | lucapa
# Processing Record 40 of Set 6 | ushtobe
# Processing Record 41 of Set 6 | inhambane
# Processing Record 42 of Set 6 | synya
# Processing Record 43 of Set 6 | pietarsaari
# Processing Record 44 of Set 6 | am timan
# Processing Record 45 of Set 6 | urdoma
# Processing Record 46 of Set 6 | macusani
# Processing Record 47 of Set 6 | diffa
# Processing Record 48 of Set 6 | patti
# Processing Record 49 of Set 6 | porto novo
# Processing Record 50 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | kapuskasing
# Processing Record 2 of Set 7 | torbay
# Processing Record 3 of Set 7 | tulsipur
# Processing Record 4 of Set 7 | coruripe
# Processing Record 5 of Set 7 | dondo
# Processing Record 6 of Set 7 | saint-pascal
# City not found. Skipping...
# Processing Record 7 of Set 7 | oranjemund
# Processing Record 8 of Set 7 | oksovskiy
# Processing Record 9 of Set 7 | san ignacio
# Processing Record 10 of Set 7 | kalomo
# City not found. Skipping...
# Processing Record 11 of Set 7 | chake chake
# Processing Record 12 of Set 7 | mizan teferi
# Processing Record 13 of Set 7 | elliot lake
# Processing Record 14 of Set 7 | grootfontein
# Processing Record 15 of Set 7 | piryion
# City not found. Skipping...
# Processing Record 16 of Set 7 | kutum
# Processing Record 17 of Set 7 | karatau
# Processing Record 18 of Set 7 | bilma
# Processing Record 19 of Set 7 | votkinsk
# Processing Record 20 of Set 7 | altamira
# Processing Record 21 of Set 7 | douentza
# Processing Record 22 of Set 7 | bosaso
# Processing Record 23 of Set 7 | bertoua
# Processing Record 24 of Set 7 | abu zabad
# Processing Record 25 of Set 7 | saldanha
# Processing Record 26 of Set 7 | putina
# Processing Record 27 of Set 7 | araguatins
# City not found. Skipping...
# Processing Record 28 of Set 7 | oum hadjer
# Processing Record 29 of Set 7 | tallahassee
# Processing Record 30 of Set 7 | solntsevo
# Processing Record 31 of Set 7 | urumqi
# Processing Record 32 of Set 7 | bacabal
# Processing Record 33 of Set 7 | kuznechnoye
# Processing Record 34 of Set 7 | sambava
# Processing Record 35 of Set 7 | kommunar
# Processing Record 36 of Set 7 | doha
# Processing Record 37 of Set 7 | punto fijo
# Processing Record 38 of Set 7 | ulvik
# Processing Record 39 of Set 7 | los llanos de aridane
# Processing Record 40 of Set 7 | borova
# Processing Record 41 of Set 7 | lasa
# Processing Record 42 of Set 7 | narsaq
# Processing Record 43 of Set 7 | maputo
# Processing Record 44 of Set 7 | richards bay
# Processing Record 45 of Set 7 | igarapava
# Processing Record 46 of Set 7 | piacabucu
# Processing Record 47 of Set 7 | carmaux
# Processing Record 48 of Set 7 | sao miguel do araguaia
# Processing Record 49 of Set 7 | villazon
# Processing Record 50 of Set 7 | wielun
# Processing Record 1 of Set 8 | eirunepe
# Processing Record 2 of Set 8 | bom jesus
# Processing Record 3 of Set 8 | leh
# Processing Record 4 of Set 8 | bridlicna
# Processing Record 5 of Set 8 | cabedelo
# Processing Record 6 of Set 8 | santo domingo
# Processing Record 7 of Set 8 | khurai
# Processing Record 8 of Set 8 | damavand
# Processing Record 9 of Set 8 | sindor
# Processing Record 10 of Set 8 | inirida
# Processing Record 11 of Set 8 | marsa matruh
# Processing Record 12 of Set 8 | fougamou
# Processing Record 13 of Set 8 | san rafael
# Processing Record 14 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 8 | seshcha
# Processing Record 16 of Set 8 | bulqize
# Processing Record 17 of Set 8 | ostrovnoy
# Processing Record 18 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 19 of Set 8 | grakhovo
# Processing Record 20 of Set 8 | farafangana
# Processing Record 21 of Set 8 | waynesville
# Processing Record 22 of Set 8 | afua
# Processing Record 23 of Set 8 | montero
# Processing Record 24 of Set 8 | maltahohe
# Processing Record 25 of Set 8 | falavarjan
# Processing Record 26 of Set 8 | portel
# Processing Record 27 of Set 8 | port blair
# Processing Record 28 of Set 8 | stokmarknes
# Processing Record 29 of Set 8 | bouna
# Processing Record 30 of Set 8 | bengkulu
# Processing Record 31 of Set 8 | abu dhabi
# Processing Record 32 of Set 8 | kulu
# Processing Record 33 of Set 8 | opuwo
# Processing Record 34 of Set 8 | muisne
# Processing Record 35 of Set 8 | sterlibashevo
# Processing Record 36 of Set 8 | camboriu
# City not found. Skipping...
# Processing Record 37 of Set 8 | callaway
# Processing Record 38 of Set 8 | filadelfia
# Processing Record 39 of Set 8 | salta
# Processing Record 40 of Set 8 | marystown
# Processing Record 41 of Set 8 | serebryansk
# Processing Record 42 of Set 8 | varsag
# Processing Record 43 of Set 8 | alford
# Processing Record 44 of Set 8 | bathsheba
# Processing Record 45 of Set 8 | melong
# Processing Record 46 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 8 | hofn
# Processing Record 48 of Set 8 | san antonio
# Processing Record 49 of Set 8 | bolu
# Processing Record 50 of Set 8 | mayumba
# Processing Record 1 of Set 9 | mortka
# Processing Record 2 of Set 9 | plettenberg bay
# Processing Record 3 of Set 9 | rawson
# Processing Record 4 of Set 9 | crossville
# Processing Record 5 of Set 9 | jacareacanga
# Processing Record 6 of Set 9 | yumaguzino
# Processing Record 7 of Set 9 | taltal
# Processing Record 8 of Set 9 | canela
# Processing Record 9 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 9 | bauchi
# Processing Record 11 of Set 9 | tigzirt
# Processing Record 12 of Set 9 | suez
# Processing Record 13 of Set 9 | puerto lempira
# Processing Record 14 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 15 of Set 9 | benguela
# Processing Record 16 of Set 9 | puerto maldonado
# Processing Record 17 of Set 9 | likasi
# Processing Record 18 of Set 9 | saint anthony
# Processing Record 19 of Set 9 | tsybuliv
# Processing Record 20 of Set 9 | villa bruzual
# Processing Record 21 of Set 9 | asfi
# Processing Record 22 of Set 9 | apac
# Processing Record 23 of Set 9 | ciro marina
# Processing Record 24 of Set 9 | brunico
# Processing Record 25 of Set 9 | viedma
# Processing Record 26 of Set 9 | portobelo
# Processing Record 27 of Set 9 | mayahi
# Processing Record 28 of Set 9 | tres arroyos
# Processing Record 29 of Set 9 | tuscaloosa
# Processing Record 30 of Set 9 | krasnyy yar
# Processing Record 31 of Set 9 | bandarbeyla
# Processing Record 32 of Set 9 | padang
# Processing Record 33 of Set 9 | apatity
# Processing Record 34 of Set 9 | belleville
# Processing Record 35 of Set 9 | jumla
# Processing Record 36 of Set 9 | mihail kogalniceanu
# Processing Record 37 of Set 9 | riesa
# Processing Record 38 of Set 9 | conceicao da barra
# Processing Record 39 of Set 9 | zilair
# Processing Record 40 of Set 9 | marsh harbour
# Processing Record 41 of Set 9 | abadiania
# Processing Record 42 of Set 9 | biltine
# Processing Record 43 of Set 9 | uray
# Processing Record 44 of Set 9 | kars
# Processing Record 45 of Set 9 | axim
# Processing Record 46 of Set 9 | kongolo
# Processing Record 47 of Set 9 | miranda de ebro
# Processing Record 48 of Set 9 | agsu
# City not found. Skipping...
# Processing Record 49 of Set 9 | horta
# Processing Record 50 of Set 9 | corovode
# Processing Record 1 of Set 10 | birjand
# Processing Record 2 of Set 10 | guanare
# Processing Record 3 of Set 10 | dubenskiy
# City not found. Skipping...
# Processing Record 4 of Set 10 | rondonopolis
# Processing Record 5 of Set 10 | kathor
# Processing Record 6 of Set 10 | umm lajj
# Processing Record 7 of Set 10 | tonj
# Processing Record 8 of Set 10 | eganville
# Processing Record 9 of Set 10 | santa fe
# Processing Record 10 of Set 10 | llanera
# Processing Record 11 of Set 10 | husavik
# Processing Record 12 of Set 10 | conde
# Processing Record 13 of Set 10 | amalapuram
# Processing Record 14 of Set 10 | birao
# Processing Record 15 of Set 10 | hornepayne
# Processing Record 16 of Set 10 | ust-koksa
# Processing Record 17 of Set 10 | ereymentau
# Processing Record 18 of Set 10 | dankov
# Processing Record 19 of Set 10 | jati
# Processing Record 20 of Set 10 | ipswich
# Processing Record 21 of Set 10 | khokhlovo
# Processing Record 22 of Set 10 | sembe
# Processing Record 23 of Set 10 | chisindia
# Processing Record 24 of Set 10 | morondava
# Processing Record 25 of Set 10 | omboue
# Processing Record 26 of Set 10 | codrington
# Processing Record 27 of Set 10 | el doncello
# Processing Record 28 of Set 10 | nathdwara
# Processing Record 29 of Set 10 | caconda
# Processing Record 30 of Set 10 | lethem
# Processing Record 31 of Set 10 | gavle
# Processing Record 32 of Set 10 | keti bandar
# Processing Record 33 of Set 10 | koplik
# Processing Record 34 of Set 10 | snezhnogorsk
# Processing Record 35 of Set 10 | sao joao da barra
# Processing Record 36 of Set 10 | barreirinhas
# Processing Record 37 of Set 10 | strezhevoy
# Processing Record 38 of Set 10 | narkevychi
# Processing Record 39 of Set 10 | kalisz
# Processing Record 40 of Set 10 | havelock
# Processing Record 41 of Set 10 | novoye atlashevo
# City not found. Skipping...
# Processing Record 42 of Set 10 | voloshka
# Processing Record 43 of Set 10 | rundu
# Processing Record 44 of Set 10 | nouadhibou
# Processing Record 45 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 46 of Set 10 | pitimbu
# Processing Record 47 of Set 10 | mananjary
# Processing Record 48 of Set 10 | el copey
# Processing Record 49 of Set 10 | tubuala
# Processing Record 50 of Set 10 | bougouni
# Processing Record 1 of Set 11 | eresos
# Processing Record 2 of Set 11 | sindand
# City not found. Skipping...
# Processing Record 3 of Set 11 | beisfjord
# Processing Record 4 of Set 11 | honningsvag
# Processing Record 5 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 6 of Set 11 | sanlucar la mayor
# Processing Record 7 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 11 | garissa
# Processing Record 9 of Set 11 | cap malheureux
# Processing Record 10 of Set 11 | aktau
# Processing Record 11 of Set 11 | veselynove
# Processing Record 12 of Set 11 | malartic
# Processing Record 13 of Set 11 | montepuez
# Processing Record 14 of Set 11 | ochakiv
# Processing Record 15 of Set 11 | chinhoyi
# Processing Record 16 of Set 11 | lipin bor
# Processing Record 17 of Set 11 | kalabo
# Processing Record 18 of Set 11 | nhamunda
# Processing Record 19 of Set 11 | ndele
# Processing Record 20 of Set 11 | ringebu
# Processing Record 21 of Set 11 | la mana
# Processing Record 22 of Set 11 | thinadhoo
# Processing Record 23 of Set 11 | westport
# Processing Record 24 of Set 11 | henties bay
# Processing Record 25 of Set 11 | praia da vitoria
# Processing Record 26 of Set 11 | afonso claudio
# Processing Record 27 of Set 11 | alassio
# Processing Record 28 of Set 11 | outjo
# Processing Record 29 of Set 11 | aksarayskiy
# Processing Record 30 of Set 11 | acarau
# Processing Record 31 of Set 11 | san gavino monreale
# Processing Record 32 of Set 11 | kozhva
# Processing Record 33 of Set 11 | bisira
# Processing Record 34 of Set 11 | vagur
# Processing Record 35 of Set 11 | krasnyy gulyay
# Processing Record 36 of Set 11 | hyeres
# Processing Record 37 of Set 11 | manicore
# Processing Record 38 of Set 11 | reo
# Processing Record 39 of Set 11 | zhovti vody
# Processing Record 40 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 11 | chaplynka
# Processing Record 42 of Set 11 | chimore
# Processing Record 43 of Set 11 | grindavik
# Processing Record 44 of Set 11 | lyantonde
# Processing Record 45 of Set 11 | illapel
# Processing Record 46 of Set 11 | gamba
# Processing Record 47 of Set 11 | mishkino
# Processing Record 48 of Set 11 | ancud
# Processing Record 49 of Set 11 | siva
# Processing Record 50 of Set 11 | vila do maio
# Processing Record 1 of Set 12 | manakara
# Processing Record 2 of Set 12 | vitoria
# Processing Record 3 of Set 12 | anloga
# Processing Record 4 of Set 12 | cassilandia
# Processing Record 5 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 6 of Set 12 | taoudenni
# Processing Record 7 of Set 12 | trifesti
# Processing Record 8 of Set 12 | havoysund
# Processing Record 9 of Set 12 | ambilobe
# Processing Record 10 of Set 12 | shelburne
# Processing Record 11 of Set 12 | farkhor
# Processing Record 12 of Set 12 | andrelandia
# Processing Record 13 of Set 12 | praia
# Processing Record 14 of Set 12 | lancaster
# Processing Record 15 of Set 12 | polovinnoye
# Processing Record 16 of Set 12 | unai
# Processing Record 17 of Set 12 | megion
# Processing Record 18 of Set 12 | hwange
# Processing Record 19 of Set 12 | mapiripan
# Processing Record 20 of Set 12 | abapo
# Processing Record 21 of Set 12 | alta floresta
# Processing Record 22 of Set 12 | mogadishu
# Processing Record 23 of Set 12 | dharchula
# Processing Record 24 of Set 12 | tasgaon
# Processing Record 25 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 26 of Set 12 | tabou
# Processing Record 27 of Set 12 | maetaguse
# City not found. Skipping...
# Processing Record 28 of Set 12 | shujaabad
# Processing Record 29 of Set 12 | apatou
# Processing Record 30 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 12 | vitry-le-francois
# Processing Record 32 of Set 12 | pyaozerskiy
# Processing Record 33 of Set 12 | loding
# Processing Record 34 of Set 12 | uravakonda
# Processing Record 35 of Set 12 | hamilton
# Processing Record 36 of Set 12 | mango
# Processing Record 37 of Set 12 | sarahan
# Processing Record 38 of Set 12 | ornskoldsvik
# Processing Record 39 of Set 12 | camamu
# Processing Record 40 of Set 12 | borazjan
# Processing Record 41 of Set 12 | hemsedal
# Processing Record 42 of Set 12 | buy
# Processing Record 43 of Set 12 | mocuba
# Processing Record 44 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 12 | fort-shevchenko
# Processing Record 46 of Set 12 | calama
# Processing Record 47 of Set 12 | road town
# Processing Record 48 of Set 12 | puerto carreno
# Processing Record 49 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 12 | aksarka
# Processing Record 1 of Set 13 | kudinovo
# Processing Record 2 of Set 13 | parabel
# Processing Record 3 of Set 13 | sharjah
# Processing Record 4 of Set 13 | terny
# Processing Record 5 of Set 13 | manadhoo
# Processing Record 6 of Set 13 | barra do garcas
# Processing Record 7 of Set 13 | hima
# Processing Record 8 of Set 13 | nokaneng
# Processing Record 9 of Set 13 | ilmajoki
# Processing Record 10 of Set 13 | kastamonu
# Processing Record 11 of Set 13 | bud
# Processing Record 12 of Set 13 | rio gallegos
# Processing Record 13 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 14 of Set 13 | antsohihy
# Processing Record 15 of Set 13 | tuljapur
# Processing Record 16 of Set 13 | todiresti
# Processing Record 17 of Set 13 | liman
# Processing Record 18 of Set 13 | sao gabriel da cachoeira
# Processing Record 19 of Set 13 | camana
# Processing Record 20 of Set 13 | joao alfredo
# Processing Record 21 of Set 13 | santa cruz cabralia
# Processing Record 22 of Set 13 | huarmey
# Processing Record 23 of Set 13 | santo antonio do sudoeste
# Processing Record 24 of Set 13 | jalu
# Processing Record 25 of Set 13 | alekseyevka
# Processing Record 26 of Set 13 | sfantu gheorghe
# Processing Record 27 of Set 13 | turukhansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you ha
len(city_data)
# Out:
# 574

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City  Cloudiness Country Current Description  Humidity      Lat  \
# 0  Krasnoarmeyskiy           1      RU           clear sky        53  47.0114
# 1       Mto Wa Mbu          36      TZ    scattered clouds        71  -3.3500
# 2      Chervishevo         100      RU     overcast clouds        84  56.9464
# 3  Arraial Do Cabo           0      BR           clear sky        83 -22.9661
# 4          Salinas           0      US           clear sky        54  36.6777
#
#         Lng  Max Temp  Wind Speed
# 0   42.2072     45.21        4.81
# 1   35.8500     69.96        4.83
# 2   65.4278     43.09        7.00
# 3  -42.0278     75.06       18.41
# 4 -121.6555     80.56       11.50

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City  Cloudiness Country Current Description  Humidity      Lat  \
# 0  Krasnoarmeyskiy           1      RU           clear sky        53  47.0114
# 1       Mto Wa Mbu          36      TZ    scattered clouds        71  -3.3500
# 2      Chervishevo         100      RU     overcast clouds        84  56.9464
# 3  Arraial Do Cabo           0      BR           clear sky        83 -22.9661
# 4          Salinas           0      US           clear sky        54  36.6777
# 5        Jamestown           0      US           clear sky        53  42.0970
# 6        Cape Town          78      ZA       broken clouds        79 -33.9258
# 7         Tessalit           4      ML           clear sky        19  20.1986
# 8        Mahebourg          20      MU          few clouds        73 -20.4081
# 9   Port Shepstone          34      ZA    scattered clouds        90 -30.7414
#
#         Lng  Max Temp  Wind Speed
# 0   42.2072     45.21        4.81
# 1   35.8500     69.96        4.83
# 2   65.4278     43.09        7.00
# 3  -42.0278     75.06       18.41
# 4 -121.6555     80.56       11.50
# 5  -79.2353     44.19       16.11
# 6   18.4232     64.09       11.01
# 7    1.0114     83.70       12.88
# 8   57.7000     70.09        5.75
# 9   30.4550     71.98       11.81

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Cloudiness', 'Country', 'Current Description', 'Humidity',
#        'Lat', 'Lng', 'Max Temp', 'Wind Speed'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]]

# Recreate the DataFrame by using the new column order
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Krasnoarmeyskiy      RU  47.0114   42.2072     45.21        53           1
# 1       Mto Wa Mbu      TZ  -3.3500   35.8500     69.96        71          36
# 2      Chervishevo      RU  56.9464   65.4278     43.09        84         100
# 3  Arraial Do Cabo      BR -22.9661  -42.0278     75.06        83           0
# 4          Salinas      US  36.6777 -121.6555     80.56        54           0
#
#    Wind Speed Current Description
# 0        4.81           clear sky
# 1        4.83    scattered clouds
# 2        7.00     overcast clouds
# 3       18.41           clear sky
# 4       11.50           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
#output csv file
output_data_file = "WeatherPy_Database.csv"
#export city data to csv
city_data_df.to_csv(output_data_file, index_label="City_ID")

# Export the city_data DataFrame into a CSV file
